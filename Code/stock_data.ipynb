# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('stock.csv')
data.head()
# Out:
#   product_name  stock
# 0    Product A   50.0
# 1    Product B   30.0
# 2    Product C   70.0
# 3    Product D   90.0
# 4    Product E   45.0

# %%
plt.figure(figsize=(8,8))
plt.pie(data['stock'], labels=data['product_name'], autopct='%1.1f%%')
plt.title('Product Stock Distribution')
plt.show()
